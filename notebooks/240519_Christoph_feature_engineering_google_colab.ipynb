# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# # Topic: EX2 - Turbofan RUL Prediction
# **Task**: Predict the remaining useful life (RUL) of turbofan engines based on given sensor data (time series data). It is a regression problem.
# **Data**: Turbofan engine degradation simulation data (NASA) - [Link](https://data.nasa.gov/dataset/Turbofan-Engine-Degradation-Simulation-Data-Set/vrks-gjie). See also in the topic [introduction notebook](https://github.com/nina-prog/damage-propagation-modeling/blob/2fb8c1a1102a48d7abbf04e4031807790a913a99/notebooks/Turbofan%20remaining%20useful%20life%20Prediction.ipynb).
#
# **Subtasks**:
# 1. Perform a deep **exploratory data analysis (EDA)** on the given data. -> 🎯 **Focus on this task**
# 2. Implement a more efficient **sliding window method** for time series data analysis.
# 3. Apply **traditional machine learning methods** (SOTA) to predict the remaining useful life. Includes data preparation, feature extraction, feature selection, model selection, and model parameter optimization.
# 4. Create **neural network models** to predict the remaining useful life. Includes different architectures like Convolutional Neural Networks (CNN), Recurrent Neural Networks (RNN), or Attention Models. Note: You can search for SOTA research papers and reproduce current state-of-the-art models.

# %% [markdown]
# # Imports + Settings

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# third-party libraries
import pandas as pd
import numpy as np
import os

import time
from tqdm.notebook import tqdm

import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import sys
sys.path.insert(0, '/content/drive/MyDrive/PSDA')

# %%
# !pip install tsfresh
# !pip install colorlog
# Out:
# Collecting tsfresh
#   Downloading tsfresh-0.20.2-py2.py3-none-any.whl (95 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.8/95.8 kB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.9.1 in /usr/local/lib/python3.10/dist-packages (from tsfresh) (2.31.0)
# Requirement already satisfied: numpy>=1.15.1 in /usr/local/lib/python3.10/dist-packages (from tsfresh) (1.25.2)
# Requirement already satisfied: pandas>=0.25.0 in /usr/local/lib/python3.10/dist-packages (from tsfresh) (2.0.3)
# Requirement already satisfied: scipy>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from tsfresh) (1.11.4)
# Requirement already satisfied: statsmodels>=0.13 in /usr/local/lib/python3.10/dist-packages (from tsfresh) (0.14.2)
# Requirement already satisfied: patsy>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from tsfresh) (0.5.6)
# Requirement already satisfied: scikit-learn>=0.22.0 in /usr/local/lib/python3.10/dist-packages (from tsfresh) (1.2.2)
# Requirement already satisfied: tqdm>=4.10.0 in /usr/local/lib/python3.10/dist-packages (from tsfresh) (4.66.4)
# Collecting stumpy>=1.7.2 (from tsfresh)
#   Downloading stumpy-1.12.0-py3-none-any.whl (169 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.1/169.1 kB 3.7 MB/s eta 0:00:00
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from tsfresh) (2.2.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25.0->tsfresh) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25.0->tsfresh) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25.0->tsfresh) (2024.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.4.1->tsfresh) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.9.1->tsfresh) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.9.1->tsfresh) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.9.1->tsfresh) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.9.1->tsfresh) (2024.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.0->tsfresh) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.0->tsfresh) (3.5.0)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.13->tsfresh) (24.0)
# Requirement already satisfied: numba>=0.55.2 in /usr/local/lib/python3.10/dist-packages (from stumpy>=1.7.2->tsfresh) (0.58.1)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.55.2->stumpy>=1.7.2->tsfresh) (0.41.1)
# Installing collected packages: stumpy, tsfresh
# Successfully installed stumpy-1.12.0 tsfresh-0.20.2
# Collecting colorlog
#   Downloading colorlog-6.8.2-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog
# Successfully installed colorlog-6.8.2

# %%
# source code
from src.utils import load_data, load_config
from src.data_preprocessing import create_rolling_windows_datasets

# %%
# settings
sns.set_style("whitegrid")
sns.set_palette("Set2")
sns.set(rc={"figure.dpi":100, 'savefig.dpi':200})
sns.set_context('notebook')

# %%
np.random.seed(42)

# %% [markdown]
# # Paths

# %%
# Make sure to execute this cell only once for one kernel session, before running any other cell below.
#os.chdir("../") # set working directory to root of project
#os.getcwd() # check current working directory

# %%
PATH_TO_CONFIG = "drive/MyDrive/PSDA/configs/config.yaml"

# %% [markdown]
# # Load Config + Data

# %%
config = load_config(PATH_TO_CONFIG) # config is dict

# %%
train_data_1, test_data_1, test_RUL_data_1 = load_data(config_path=PATH_TO_CONFIG, dataset_num=1)
# Out:
# 2024-05-19 16:45:49 [src.utils:60] [INFO] >>>> Loading data set 1...
# INFO:src.utils:Loading data set 1...
# 2024-05-19 16:45:50 [src.utils:89] [INFO] >>>> Loaded raw data for dataset 1.
# INFO:src.utils:Loaded raw data for dataset 1.
# 2024-05-19 16:45:50 [src.utils:90] [INFO] >>>> Train Data: (20631, 26)
# INFO:src.utils:Train Data: (20631, 26)
# 2024-05-19 16:45:50 [src.utils:91] [INFO] >>>> Test Data: (13096, 26)
# INFO:src.utils:Test Data: (13096, 26)
# 2024-05-19 16:45:50 [src.utils:92] [INFO] >>>> Test RUL Data: (100, 1)
# INFO:src.utils:Test RUL Data: (100, 1)

# %%
train_data_2, test_data_2, test_RUL_data_2 = load_data(config_path=PATH_TO_CONFIG, dataset_num=2)
# Out:
# 2024-05-19 16:45:52 [src.utils:60] [INFO] >>>> Loading data set 2...
# INFO:src.utils:Loading data set 2...
# 2024-05-19 16:45:54 [src.utils:89] [INFO] >>>> Loaded raw data for dataset 2.
# INFO:src.utils:Loaded raw data for dataset 2.
# 2024-05-19 16:45:54 [src.utils:90] [INFO] >>>> Train Data: (53759, 26)
# INFO:src.utils:Train Data: (53759, 26)
# 2024-05-19 16:45:54 [src.utils:91] [INFO] >>>> Test Data: (33991, 26)
# INFO:src.utils:Test Data: (33991, 26)
# 2024-05-19 16:45:54 [src.utils:92] [INFO] >>>> Test RUL Data: (259, 1)
# INFO:src.utils:Test RUL Data: (259, 1)

# %%
train_data_3, test_data_3, test_RUL_data_3 = load_data(config_path=PATH_TO_CONFIG, dataset_num=3)
# Out:
# 2024-05-19 16:45:55 [src.utils:60] [INFO] >>>> Loading data set 3...
# INFO:src.utils:Loading data set 3...
# 2024-05-19 16:45:56 [src.utils:89] [INFO] >>>> Loaded raw data for dataset 3.
# INFO:src.utils:Loaded raw data for dataset 3.
# 2024-05-19 16:45:56 [src.utils:90] [INFO] >>>> Train Data: (24720, 26)
# INFO:src.utils:Train Data: (24720, 26)
# 2024-05-19 16:45:56 [src.utils:91] [INFO] >>>> Test Data: (16596, 26)
# INFO:src.utils:Test Data: (16596, 26)
# 2024-05-19 16:45:56 [src.utils:92] [INFO] >>>> Test RUL Data: (100, 1)
# INFO:src.utils:Test RUL Data: (100, 1)

# %%
train_data_4, test_data_4, test_RUL_data_4 = load_data(config_path=PATH_TO_CONFIG, dataset_num=4)
# Out:
# 2024-05-19 16:45:57 [src.utils:60] [INFO] >>>> Loading data set 4...
# INFO:src.utils:Loading data set 4...
# 2024-05-19 16:45:59 [src.utils:89] [INFO] >>>> Loaded raw data for dataset 4.
# INFO:src.utils:Loaded raw data for dataset 4.
# 2024-05-19 16:45:59 [src.utils:90] [INFO] >>>> Train Data: (61249, 26)
# INFO:src.utils:Train Data: (61249, 26)
# 2024-05-19 16:45:59 [src.utils:91] [INFO] >>>> Test Data: (41214, 26)
# INFO:src.utils:Test Data: (41214, 26)
# 2024-05-19 16:45:59 [src.utils:92] [INFO] >>>> Test RUL Data: (248, 1)
# INFO:src.utils:Test RUL Data: (248, 1)

# %% [markdown]
# # 📍 Subtask 1: Feature Extraction

# %% [markdown]
# ### Feature Extraction with tsfresh

# %%
from tsfresh.feature_extraction.settings import MinimalFCParameters, EfficientFCParameters, ComprehensiveFCParameters

# %%
features_all = ComprehensiveFCParameters()
features_eff = EfficientFCParameters()
features_minimal = MinimalFCParameters()
# Out:
# WARNING:tsfresh.feature_extraction.settings:Dependency not available for matrix_profile, this feature will be disabled!
# WARNING:tsfresh.feature_extraction.settings:Dependency not available for matrix_profile, this feature will be disabled!
# WARNING:tsfresh.feature_extraction.settings:Dependency not available for matrix_profile, this feature will be disabled!

# %%
features_all.keys() ^ features_eff.keys()
# Out:
# {'approximate_entropy', 'sample_entropy'}

# %% [markdown]
# Findings: The differences between efficient and all features are two features which have a very high computational cost which is why these two features are not further investigated.

# %% [markdown]
# Dataset 1

# %% [markdown]
# There is a bug in extracting the RUL in create_rolling_windows_datasets

# %%
np.random.seed(seed=5)
random_indices = np.arange(1, 101)
np.random.shuffle(random_indices)

train_data_1_sample = train_data_1[train_data_1['UnitNumber'].isin(random_indices[:10])]

# %%
train_data_1_rolling = create_rolling_windows_datasets(train_data_1_sample, test_data_1, test_RUL_data_1, max_timeshift=20, min_timeshift=5, feature_extraction_mode='efficient')
# Out:
# WARNING:tsfresh.feature_extraction.settings:Dependency not available for matrix_profile, this feature will be disabled!
# 2024-05-19 16:34:52 [src.data_preprocessing:78] [INFO] >>>> Creating rolling windows for train data...
# INFO:src.data_preprocessing:Creating rolling windows for train data...
# Rolling: 100%|██████████| 313/313 [00:05<00:00, 58.13it/s]
# 2024-05-19 16:34:57 [src.data_preprocessing:82] [INFO] >>>> Extracting features for train data...
# INFO:src.data_preprocessing:Extracting features for train data...
# Feature Extraction:  21%|██        | 10187/48096 [09:53<36:46, 17.18it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-7e7d02b3f159> in <cell line: 1>()
# ----> 1 train_data_1_rolling = create_rolling_windows_datasets(train_data_1_sample, test_data_1, test_RUL_data_1, max_timeshift=20, min_timeshift=5, feature_extraction_mode='efficient')
#
# /content/drive/MyDrive/PSDA/src/data_preprocessing.py in create_rolling_windows_datasets(train_data, test_data, test_RUL_data, column_id, column_sort, max_timeshift, min_timeshift, feature_extraction_mode)
#      81
#      82     logger.info("Extracting features for train data...")
# ---> 83     X_train = extract_features(train_data_rolled.drop([column_id], axis=1),
#      84                                column_id="id", column_sort=column_sort,
#      85                                default_fc_parameters=default_fc_parameters,
#
# /usr/local/lib/python3.10/dist-packages/tsfresh/feature_extraction/extraction.py in extract_features(timeseries_container, default_fc_parameters, kind_to_fc_parameters, column_id, column_sort, column_kind, column_value, chunksize, n_jobs, show_warnings, disable_progressbar, impute_function, profile, profiling_filename, profiling_sorting, distributor, pivot)
#     162             warnings.simplefilter("default")
#     163
# --> 164         result = _do_extraction(
#     165             df=timeseries_container,
#     166             column_id=column_id,
#
# /usr/local/lib/python3.10/dist-packages/tsfresh/feature_extraction/extraction.py in _do_extraction(df, column_id, column_value, column_kind, column_sort, default_fc_parameters, kind_to_fc_parameters, n_jobs, chunk_size, disable_progressbar, show_warnings, distributor, pivot)
#     292     )
#     293
# --> 294     result = distributor.map_reduce(
#     295         _do_extraction_on_chunk,
#     296         data=data,
#
# /usr/local/lib/python3.10/dist-packages/tsfresh/utilities/distribution.py in map_reduce(self, map_function, data, function_kwargs, chunk_size, data_length)
#     239             )
#     240
# --> 241         result = list(itertools.chain.from_iterable(result))
#     242
#     243         self.close()
#
# /usr/local/lib/python3.10/dist-packages/tqdm/std.py in __iter__(self)
#    1179
#    1180         try:
# -> 1181             for obj in iterable:
#    1182                 yield obj
#    1183                 # Update and possibly print the progressbar.
#
# /usr/local/lib/python3.10/dist-packages/tsfresh/utilities/distribution.py in _function_with_partly_reduce(chunk_list, map_function, kwargs)
#      41     kwargs = kwargs or {}
#      42     results = (map_function(chunk, **kwargs) for chunk in chunk_list)
# ---> 43     results = list(itertools.chain.from_iterable(results))
#      44     return results
#      45
#
# /usr/local/lib/python3.10/dist-packages/tsfresh/utilities/distribution.py in <genexpr>(.0)
#      40     """
#      41     kwargs = kwargs or {}
# ---> 42     results = (map_function(chunk, **kwargs) for chunk in chunk_list)
#      43     results = list(itertools.chain.from_iterable(results))
#      44     return results
#
# /usr/local/lib/python3.10/dist-packages/tsfresh/feature_extraction/extraction.py in _do_extraction_on_chunk(chunk, default_fc_parameters, kind_to_fc_parameters, show_warnings)
#     384             warnings.simplefilter("default")
#     385
# --> 386         return list(_f())
#
# /usr/local/lib/python3.10/dist-packages/tsfresh/feature_extraction/extraction.py in _f()
#     372                     result = [("", func(x))]
#     373
# --> 374             for key, item in result:
#     375                 feature_name = str(kind) + "__" + func.__name__
#     376                 if key:
#
# /usr/local/lib/python3.10/dist-packages/tsfresh/feature_extraction/extraction.py in <genexpr>(.0)
#     366                 if parameter_list:
#     367                     result = (
# --> 368                         (convert_to_output_format(param), func(x, **param))
#     369                         for param in parameter_list
#     370                     )
#
# /usr/local/lib/python3.10/dist-packages/tsfresh/feature_extraction/feature_calculators.py in change_quantiles(x, ql, qh, isabs, f_agg)
#    1524     # other will be np.NaN
#    1525     try:
# -> 1526         bin_cat = pd.qcut(x, [ql, qh], labels=False)
#    1527         bin_cat_0 = bin_cat == 0
#    1528     except ValueError:  # Occurs when ql are qh effectively equal, e.g. x is not long enough or is too categorical
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/tile.py in qcut(x, q, labels, retbins, precision, duplicates)
#     377     bins = np.quantile(x_np, quantiles)
#     378
# --> 379     fac, bins = _bins_to_cuts(
#     380         x,
#     381         bins,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/tile.py in _bins_to_cuts(x, bins, right, labels, precision, include_lowest, dtype, duplicates, ordered)
#     415         return result, bins
#     416
# --> 417     unique_bins = algos.unique(bins)
#     418     if len(unique_bins) < len(bins) and len(bins) != 2:
#     419         if duplicates == "raise":
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/algorithms.py in unique(values)
#     388     array([('a', 'b'), ('b', 'a'), ('a', 'c')], dtype=object)
#     389     """
# --> 390     return unique_with_mask(values)
#     391
#     392
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/algorithms.py in unique_with_mask(values, mask)
#     423
#     424     original = values
# --> 425     hashtable, values = _get_hashtable_algo(values)
#     426
#     427     table = hashtable(len(values))
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/algorithms.py in _get_hashtable_algo(values)
#     260     values : ndarray
#     261     """
# --> 262     values = _ensure_data(values)
#     263
#     264     ndtype = _check_object_for_strings(values)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/algorithms.py in _ensure_data(values)
#     163         # error: Item "ExtensionDtype" of "Union[Any, ExtensionDtype, dtype[Any]]"
#     164         # has no attribute "itemsize"
# --> 165         if values.dtype.itemsize in [2, 12, 16]:  # type: ignore[union-attr]
#     166             # we dont (yet) have float128 hashtable support
#     167             return ensure_float64(values)
#
# KeyboardInterrupt:

# %%
X_train, y_train, X_test, y_test = train_data_1_rolling
timestamp = time.strftime("%Y%m%d-%H%M%S")
X_train.to_pickle(f"{config['paths']['processed_data_dir']}ex2_train_data_1_max_20_min_5_sample_10_{timestamp}.pkl")
y_train.to_pickle(f"{config['paths']['processed_data_dir']}ex2_rul_train_data_1_max_20_min_5_sample_10_{timestamp}.pkl")
X_test.to_pickle(f"{config['paths']['processed_data_dir']}ex2_test_data_1_max_20_min_5_sample_10_{timestamp}.pkl")
y_test.to_pickle(f"{config['paths']['processed_data_dir']}ex2_rul_test_data_1_max_20_min_5_sample_10_{timestamp}.pkl")

# %%
#Check if data is saved
pd.read_pickle('drive/MyDrive/PSDA/data/processed/ex2_train_data_2_max_20_min_5_sample_10_20240515-160124.pkl')

# %% [markdown]
# Dataset 2

# %%
np.random.seed(seed=4)
random_indices = np.arange(1, 101)
np.random.shuffle(random_indices)

train_data_2_sample = train_data_2[train_data_2['UnitNumber'].isin(random_indices[:10])]

# %%
train_data_2_rolling = create_rolling_windows_datasets(train_data_2_sample, test_data_2, test_RUL_data_2, max_timeshift=20, min_timeshift=5, feature_extraction_mode='efficient')

# %%
X_train, y_train, X_test, y_test = train_data_2_rolling
timestamp = time.strftime("%Y%m%d-%H%M%S")
X_train.to_pickle(f"{config['paths']['processed_data_dir']}ex2_train_data_2_max_20_min_5_sample_10_{timestamp}.pkl")
y_train.to_pickle(f"{config['paths']['processed_data_dir']}ex2_rul_train_data_2_max_20_min_5_sample_10_{timestamp}.pkl")
X_test.to_pickle(f"{config['paths']['processed_data_dir']}ex2_test_data_2_max_20_min_5_sample_10_{timestamp}.pkl")
y_test.to_pickle(f"{config['paths']['processed_data_dir']}ex2_rul_test_data_2_max_20_min_5_sample_10_{timestamp}.pkl")

# %%
#Check if data is saved
pd.read_pickle('drive/MyDrive/PSDA/data/processed/ex2_train_data_2_max_20_min_5_sample_10_20240515-160124.pkl')

# %% [markdown]
# Dataset 3

# %%
np.random.seed(seed=8743)
random_indices = np.arange(1, 101)
np.random.shuffle(random_indices)

train_data_3_sample = train_data_3[train_data_3['UnitNumber'].isin(random_indices[:10])]

# %%
train_data_3_rolling = create_rolling_windows_datasets(train_data_3_sample, test_data_3, test_RUL_data_3, max_timeshift=20, min_timeshift=5, feature_extraction_mode='efficient')

# %%
train_data_3_rolling = create_rolling_windows_datasets(train_data_3_sample, test_data_3, test_RUL_data_3, max_timeshift=20, min_timeshift=5, feature_extraction_mode='efficient')

# %%
X_train, y_train, X_test, y_test = train_data_3_rolling
timestamp = time.strftime("%Y%m%d-%H%M%S")
X_train.to_pickle(f"{config['paths']['processed_data_dir']}ex2_train_data_3_max_20_min_5_sample_10_{timestamp}.pkl")
y_train.to_pickle(f"{config['paths']['processed_data_dir']}ex2_rul_train_data_3_max_20_min_5_sample_10_{timestamp}.pkl")
X_test.to_pickle(f"{config['paths']['processed_data_dir']}ex2_test_data_3_max_20_min_5_sample_10_{timestamp}.pkl")
y_test.to_pickle(f"{config['paths']['processed_data_dir']}ex2_rul_test_data_3_max_20_min_5_sample_10_{timestamp}.pkl")

# %%
#Check if data is saved
pd.read_pickle('drive/MyDrive/PSDA/data/processed/ex2_train_data_3_max_20_min_5_sample_10_20240516-075646.pkl')

# %% [markdown]
# Dataset 4

# %%
np.random.seed(seed=532)
random_indices = np.arange(1, 101)
np.random.shuffle(random_indices)

train_data_4_sample = train_data_4[train_data_4['UnitNumber'].isin(random_indices[:10])]

# %%
train_data_4_rolling = create_rolling_windows_datasets(train_data_4_sample, test_data_4, test_RUL_data_4, max_timeshift=15, min_timeshift=5, feature_extraction_mode='efficient')

# %%
X_train, y_train, X_test, y_test = train_data_4_rolling
timestamp = time.strftime("%Y%m%d-%H%M%S")
X_train.to_pickle(f"{config['paths']['processed_data_dir']}ex2_train_data_4_max_15_min_5_sample_10_{timestamp}.pkl")
y_train.to_pickle(f"{config['paths']['processed_data_dir']}ex2_rul_train_data_4_max_15_min_5_sample_10_{timestamp}.pkl")
X_test.to_pickle(f"{config['paths']['processed_data_dir']}ex2_test_data_4_max_15_min_5_sample_10_{timestamp}.pkl")
y_test.to_pickle(f"{config['paths']['processed_data_dir']}ex2_rul_test_data_4_max_15_min_5_sample_10_{timestamp}.pkl")

# %%
#Check if data is saved
pd.read_pickle('drive/MyDrive/PSDA/data/processed/ex2_topic_train_data_4_max_20_min_5_sample_10_20240515-160124.pkl')

# %% [markdown]
# ___________________
# Import Datasets
# ____________________

# %%
# Import uploaded data to avoid a collection everytime
#pd.read_pickle('drive/MyDrive/PSDA/data/processed/XXX')

ds1_train = pd.read_pickle('drive/MyDrive/PSDA/data/processed/ex2_train_data_1_max_20_min_5_sample_10_20240516-070658.pkl')
ds2_train = pd.read_pickle('drive/MyDrive/PSDA/data/processed/ex2_train_data_2_max_20_min_5_sample_10_20240515-160124.pkl')
ds3_train = pd.read_pickle('drive/MyDrive/PSDA/data/processed/ex2_train_data_3_max_20_min_5_sample_10_20240516-075646.pkl')
ds4_train = pd.read_pickle('drive/MyDrive/PSDA/data/processed/ex2_train_data_4_max_15_min_5_sample_10_20240519-095800.pkl')

# %%
ds1_test = pd.read_pickle('drive/MyDrive/PSDA/data/processed/ex2_test_data_1_max_20_min_5_sample_10_20240516-070658.pkl')
ds2_test = pd.read_pickle('drive/MyDrive/PSDA/data/processed/ex2_test_data_2_max_20_min_5_sample_10_20240515-160124.pkl')
ds3_test = pd.read_pickle('drive/MyDrive/PSDA/data/processed/ex2_test_data_3_max_20_min_5_sample_10_20240516-075646.pkl')
ds4_test = pd.read_pickle('drive/MyDrive/PSDA/data/processed/ex2_test_data_4_max_15_min_5_sample_10_20240519-095800.pkl')

# %%
ds1_rul_train = pd.read_pickle('drive/MyDrive/PSDA/data/processed/ex2_rul_train_data_1_max_20_min_5_sample_10_20240519-090004.pkl')
ds2_rul_train = pd.read_pickle('drive/MyDrive/PSDA/data/processed/ex2_rul_train_data_2_max_20_min_5_sample_10_20240519-090004.pkl')
ds3_rul_train = pd.read_pickle('drive/MyDrive/PSDA/data/processed/ex2_rul_train_data_3_max_20_min_5_sample_10_20240519-090004.pkl')
ds4_rul_train = pd.read_pickle('drive/MyDrive/PSDA/data/processed/ex2_rul_train_data_4_max_15_min_5_sample_10_20240519-095800.pkl')

# %%
ds1_rul_test = pd.read_pickle('drive/MyDrive/PSDA/data/processed/ex2_rul_test_data_1_max_20_min_5_sample_10_20240516-070658.pkl')
ds2_rul_test = pd.read_pickle('drive/MyDrive/PSDA/data/processed/ex2_rul_test_data_2_max_20_min_5_sample_10_20240515-160124.pkl')
ds3_rul_test = pd.read_pickle('drive/MyDrive/PSDA/data/processed/ex2_rul_test_data_3_max_20_min_5_sample_10_20240516-075646.pkl')
ds4_rul_test = pd.read_pickle('drive/MyDrive/PSDA/data/processed/ex2_rul_test_data_4_max_15_min_5_sample_10_20240519-095800.pkl')

# %% [markdown]
# Features Analysis

# %%
print(ds1_train.shape, ds1_rul_train.shape)
print(ds2_train.shape, ds2_rul_train.shape)
print(ds3_train.shape, ds3_rul_train.shape)
print(ds4_train.shape, ds4_rul_train.shape)
# Out:
# (2004, 18648) (2054, 1)
# (2048, 18648) (2098, 1)
# (2101, 18648) (2151, 1)
# (2153, 18648) (2153, 1)

# %% [markdown]
# Findings/Notes: shape for rul and data is not fitting!

# %%
print(ds1_test.shape, ds1_rul_test.shape)
print(ds2_test.shape, ds2_rul_test.shape)
print(ds3_test.shape, ds3_rul_test.shape)
print(ds4_test.shape, ds4_rul_test.shape)
# Out:
# (100, 18648) (100, 1)
# (259, 18648) (259, 1)
# (100, 18648) (100, 1)
# (248, 18648) (248, 1)

# %%
print(ds4_train.shape)
ds4_train["RUL"] = ds4_rul_train
print(ds4_train.shape)
# Out:
# (2153, 18648)
# (2153, 18649)

# %%
correlation = ds4_train.corr()

# %%
correlation.to_pickle("drive/MyDrive/PSDA/data/processed/dataset4_correlation_matrix.pkl")

# %%
corr_rul = []
for i in range(0,ds4_train.shape(1)-1):
  if ds4_train["RUL"].corr(ds4_train[i])
# Out:
# ---------------------------------------------------------------------------
# SyntaxError                               Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/IPython/core/compilerop.py in ast_parse(self, source, filename, symbol)
#      99         Arguments are exactly the same as ast.parse (in the standard library),
#     100         and are passed to the built-in compile function."""
# --> 101         return compile(source, filename, symbol, self.flags | PyCF_ONLY_AST, 1)
#     102
#     103     def reset_compiler_flags(self):
#
# SyntaxError: expected ':' (<ipython-input-30-131ed6714ae8>, line 3)

# %%
corr_rul = correlation["RUL"]
cd = corr_rul.dropna()
list_corr25_ds4 = []
for i in range(0,len(cd)):
    if cd.iloc[i] < 0.25 and cd.iloc[i] > -0.25:
        list_corr25_ds4.append(cd.index[i])



print(list_corr25_ds4)
cdd = cd.drop(list_corr25_ds4, inplace=False)
cddo = cdd.abs().sort_values(kind='quicksort',ascending=False)
print(cd.shape, cdd.shape)
# Out:
# ['Operation Setting 1__has_duplicate_max', 'Operation Setting 1__has_duplicate_min', 'Operation Setting 1__has_duplicate', 'Operation Setting 1__mean_abs_change', 'Operation Setting 1__mean_change', 'Operation Setting 1__mean_second_derivative_central', 'Operation Setting 1__median', 'Operation Setting 1__mean', 'Operation Setting 1__length', 'Operation Setting 1__standard_deviation', 'Operation Setting 1__variation_coefficient', 'Operation Setting 1__variance', 'Operation Setting 1__skewness', 'Operation Setting 1__kurtosis', 'Operation Setting 1__root_mean_square', 'Operation Setting 1__absolute_sum_of_changes', 'Operation Setting 1__longest_strike_below_mean', 'Operation Setting 1__longest_strike_above_mean', 'Operation Setting 1__count_above_mean', 'Operation Setting 1__count_below_mean', 'Operation Setting 1__last_location_of_maximum', 'Operation Setting 1__first_location_of_maximum', 'Operation Setting 1__last_location_of_minimum', 'Operation Setting 1__first_location_of_minimum', 'Operation Setting 1__percentage_of_reoccurring_values_to_all_values', 'Operation Setting 1__percentage_of_reoccurring_datapoints_to_all_datapoints', 'Operation Setting 1__sum_of_reoccurring_values', 'Operation Setting 1__sum_of_reoccurring_data_points', 'Operation Setting 1__ratio_value_number_to_time_series_length', 'Operation Setting 1__maximum', 'Operation Setting 1__absolute_maximum', 'Operation Setting 1__minimum', 'Operation Setting 1__benford_correlation', 'Operation Setting 1__time_reversal_asymmetry_statistic__lag_1', 'Operation Setting 1__time_reversal_asymmetry_statistic__lag_2', 'Operation Setting 1__time_reversal_asymmetry_statistic__lag_3', 'Operation Setting 1__c3__lag_1', 'Operation Setting 1__c3__lag_2', 'Operation Setting 1__c3__lag_3', 'Operation Setting 1__cid_ce__normalize_True', 'Operation Setting 1__cid_ce__normalize_False', 'Operation Setting 1__symmetry_looking__r_0.05', 'Operation Setting 1__symmetry_looking__r_0.1', 'Operation Setting 1__symmetry_looking__r_0.15000000000000002', 'Operation Setting 1__symmetry_looking__r_0.2', 'Operation Setting 1__symmetry_looking__r_0.25', 'Operation Setting 1__symmetry_looking__r_0.30000000000000004', 'Operation Setting 1__large_standard_deviation__r_0.25', 'Operation Setting 1__large_standard_deviation__r_0.30000000000000004', 'Operation Setting 1__large_standard_deviation__r_0.35000000000000003', 'Operation Setting 1__large_standard_deviation__r_0.4', 'Operation Setting 1__quantile__q_0.1', 'Operation Setting 1__quantile__q_0.2', 'Operation Setting 1__quantile__q_0.3', 'Operation Setting 1__quantile__q_0.4', 'Operation Setting 1__quantile__q_0.6', 'Operation Setting 1__quantile__q_0.7', 'Operation Setting 1__quantile__q_0.8', 'Operation Setting 1__quantile__q_0.9', 'Operation Setting 1__autocorrelation__lag_0', 'Operation Setting 1__autocorrelation__lag_1', 'Operation Setting 1__autocorrelation__lag_2', 'Operation Setting 1__autocorrelation__lag_3', 'Operation Setting 1__autocorrelation__lag_4', 'Operation Setting 1__autocorrelation__lag_5', 'Operation Setting 1__autocorrelation__lag_6', 'Operation Setting 1__autocorrelation__lag_7', 'Operation Setting 1__autocorrelation__lag_8', 'Operation Setting 1__autocorrelation__lag_9', 'Operation Setting 1__agg_autocorrelation__f_agg_"mean"__maxlag_40', 'Operation Setting 1__agg_autocorrelation__f_agg_"median"__maxlag_40', 'Operation Setting 1__agg_autocorrelation__f_agg_"var"__maxlag_40', 'Operation Setting 1__partial_autocorrelation__lag_1', 'Operation Setting 1__partial_autocorrelation__lag_2', 'Operation Setting 1__partial_autocorrelation__lag_3', 'Operation Setting 1__partial_autocorrelation__lag_4', 'Operation Setting 1__partial_autocorrelation__lag_5', 'Operation Setting 1__partial_autocorrelation__lag_6', 'Operation Setting 1__partial_autocorrelation__lag_7', 'Operation Setting 1__number_cwt_peaks__n_1', 'Operation Setting 1__number_cwt_peaks__n_5', 'Operation Setting 1__number_peaks__n_1', 'Operation Setting 1__number_peaks__n_3', ...
# (7888,) (45,)

# %%
corr_rul = correlation["RUL"]
cd = corr_rul.dropna()
list_corr1_ds4 = []
for i in range(0,len(cd)):
    if cd.iloc[i] < 0.1 and cd.iloc[i] > -0.1:
        list_corr1_ds4.append(cd.index[i])

print(list_corr1_ds4)
cdd = cd.drop(list_corr1_ds4, inplace=False)
cddo = cdd.abs().sort_values(kind='quicksort',ascending=False)
print(cd.shape, cdd.shape)
# Out:
# ['Operation Setting 1__has_duplicate_max', 'Operation Setting 1__has_duplicate_min', 'Operation Setting 1__has_duplicate', 'Operation Setting 1__mean_abs_change', 'Operation Setting 1__mean_change', 'Operation Setting 1__mean_second_derivative_central', 'Operation Setting 1__standard_deviation', 'Operation Setting 1__variance', 'Operation Setting 1__kurtosis', 'Operation Setting 1__absolute_sum_of_changes', 'Operation Setting 1__count_above_mean', 'Operation Setting 1__last_location_of_maximum', 'Operation Setting 1__first_location_of_maximum', 'Operation Setting 1__last_location_of_minimum', 'Operation Setting 1__first_location_of_minimum', 'Operation Setting 1__percentage_of_reoccurring_values_to_all_values', 'Operation Setting 1__percentage_of_reoccurring_datapoints_to_all_datapoints', 'Operation Setting 1__sum_of_reoccurring_values', 'Operation Setting 1__sum_of_reoccurring_data_points', 'Operation Setting 1__ratio_value_number_to_time_series_length', 'Operation Setting 1__maximum', 'Operation Setting 1__absolute_maximum', 'Operation Setting 1__minimum', 'Operation Setting 1__time_reversal_asymmetry_statistic__lag_1', 'Operation Setting 1__time_reversal_asymmetry_statistic__lag_2', 'Operation Setting 1__time_reversal_asymmetry_statistic__lag_3', 'Operation Setting 1__cid_ce__normalize_True', 'Operation Setting 1__cid_ce__normalize_False', 'Operation Setting 1__symmetry_looking__r_0.05', 'Operation Setting 1__symmetry_looking__r_0.15000000000000002', 'Operation Setting 1__symmetry_looking__r_0.2', 'Operation Setting 1__symmetry_looking__r_0.25', 'Operation Setting 1__symmetry_looking__r_0.30000000000000004', 'Operation Setting 1__large_standard_deviation__r_0.25', 'Operation Setting 1__large_standard_deviation__r_0.30000000000000004', 'Operation Setting 1__large_standard_deviation__r_0.35000000000000003', 'Operation Setting 1__large_standard_deviation__r_0.4', 'Operation Setting 1__quantile__q_0.2', 'Operation Setting 1__autocorrelation__lag_0', 'Operation Setting 1__autocorrelation__lag_1', 'Operation Setting 1__autocorrelation__lag_3', 'Operation Setting 1__autocorrelation__lag_5', 'Operation Setting 1__autocorrelation__lag_6', 'Operation Setting 1__autocorrelation__lag_7', 'Operation Setting 1__autocorrelation__lag_8', 'Operation Setting 1__autocorrelation__lag_9', 'Operation Setting 1__agg_autocorrelation__f_agg_"mean"__maxlag_40', 'Operation Setting 1__agg_autocorrelation__f_agg_"median"__maxlag_40', 'Operation Setting 1__agg_autocorrelation__f_agg_"var"__maxlag_40', 'Operation Setting 1__partial_autocorrelation__lag_1', 'Operation Setting 1__partial_autocorrelation__lag_3', 'Operation Setting 1__partial_autocorrelation__lag_5', 'Operation Setting 1__partial_autocorrelation__lag_6', 'Operation Setting 1__partial_autocorrelation__lag_7', 'Operation Setting 1__number_cwt_peaks__n_5', 'Operation Setting 1__number_peaks__n_3', 'Operation Setting 1__number_peaks__n_5', 'Operation Setting 1__binned_entropy__max_bins_10', 'Operation Setting 1__index_mass_quantile__q_0.1', 'Operation Setting 1__index_mass_quantile__q_0.2', 'Operation Setting 1__index_mass_quantile__q_0.3', 'Operation Setting 1__index_mass_quantile__q_0.4', 'Operation Setting 1__index_mass_quantile__q_0.6', 'Operation Setting 1__index_mass_quantile__q_0.7', 'Operation Setting 1__index_mass_quantile__q_0.8', 'Operation Setting 1__index_mass_quantile__q_0.9', 'Operation Setting 1__cwt_coefficients__coeff_0__w_2__widths_(2, 5, 10, 20)', 'Operation Setting 1__cwt_coefficients__coeff_0__w_5__widths_(2, 5, 10, 20)', 'Operation Setting 1__cwt_coefficients__coeff_1__w_2__widths_(2, 5, 10, 20)', 'Operation Setting 1__cwt_coefficients__coeff_1__w_5__widths_(2, 5, 10, 20)', 'Operation Setting 1__cwt_coefficients__coeff_2__w_2__widths_(2, 5, 10, 20)', 'Operation Setting 1__cwt_coefficients__coeff_2__w_5__widths_(2, 5, 10, 20)', 'Operation Setting 1__cwt_coefficients__coeff_3__w_2__widths_(2, 5, 10, 20)', 'Operation Setting 1__cwt_coefficients__coeff_3__w_5__widths_(2, 5, 1 ...
# (7888,) (1925,)

# %%
print(len(list_corr1_ds4))
print(len(list_corr25_ds4))
# Out:
# 5963
# 7843

# %%
print(ds4_train.iloc[:,1])
#print(ds4_train.columns[1])
# Out:
# UnitNumber  Cycle
# 5           6        0.0
#             7        0.0
#             8        0.0
#             9        0.0
#             10       0.0
#                     ...
# 93          192      0.0
#             193      0.0
#             194      0.0
#             195      0.0
#             196      0.0
# Name: Operation Setting 1__has_duplicate_max, Length: 2153, dtype: float64

# %%
list_const_ds4 = []

for i in  range(0, ds4_train.shape[1]):
  if max(ds4_train.iloc[:,i]) == min(ds4_train.iloc[:,i]):
     list_const_ds4.append(ds4_train.columns[i])

# %%
print(list_const_ds4)
print(len(list_const_ds4))
# Out:
# ['Operation Setting 1__variance_larger_than_standard_deviation', 'Operation Setting 1__symmetry_looking__r_0.0', 'Operation Setting 1__symmetry_looking__r_0.35000000000000003', 'Operation Setting 1__symmetry_looking__r_0.4', 'Operation Setting 1__symmetry_looking__r_0.45', 'Operation Setting 1__symmetry_looking__r_0.5', 'Operation Setting 1__symmetry_looking__r_0.55', 'Operation Setting 1__symmetry_looking__r_0.6000000000000001', 'Operation Setting 1__symmetry_looking__r_0.65', 'Operation Setting 1__symmetry_looking__r_0.7000000000000001', 'Operation Setting 1__symmetry_looking__r_0.75', 'Operation Setting 1__symmetry_looking__r_0.8', 'Operation Setting 1__symmetry_looking__r_0.8500000000000001', 'Operation Setting 1__symmetry_looking__r_0.9', 'Operation Setting 1__symmetry_looking__r_0.9500000000000001', 'Operation Setting 1__large_standard_deviation__r_0.05', 'Operation Setting 1__large_standard_deviation__r_0.1', 'Operation Setting 1__large_standard_deviation__r_0.15000000000000002', 'Operation Setting 1__large_standard_deviation__r_0.2', 'Operation Setting 1__large_standard_deviation__r_0.45', 'Operation Setting 1__large_standard_deviation__r_0.5', 'Operation Setting 1__large_standard_deviation__r_0.55', 'Operation Setting 1__large_standard_deviation__r_0.6000000000000001', 'Operation Setting 1__large_standard_deviation__r_0.65', 'Operation Setting 1__large_standard_deviation__r_0.7000000000000001', 'Operation Setting 1__large_standard_deviation__r_0.75', 'Operation Setting 1__large_standard_deviation__r_0.8', 'Operation Setting 1__large_standard_deviation__r_0.8500000000000001', 'Operation Setting 1__large_standard_deviation__r_0.9', 'Operation Setting 1__large_standard_deviation__r_0.9500000000000001', 'Operation Setting 1__partial_autocorrelation__lag_0', 'Operation Setting 1__partial_autocorrelation__lag_8', 'Operation Setting 1__partial_autocorrelation__lag_9', 'Operation Setting 1__number_peaks__n_10', 'Operation Setting 1__number_peaks__n_50', 'Operation Setting 1__ar_coefficient__coeff_0__k_10', 'Operation Setting 1__ar_coefficient__coeff_1__k_10', 'Operation Setting 1__ar_coefficient__coeff_2__k_10', 'Operation Setting 1__ar_coefficient__coeff_3__k_10', 'Operation Setting 1__ar_coefficient__coeff_4__k_10', 'Operation Setting 1__ar_coefficient__coeff_5__k_10', 'Operation Setting 1__ar_coefficient__coeff_6__k_10', 'Operation Setting 1__ar_coefficient__coeff_7__k_10', 'Operation Setting 1__ar_coefficient__coeff_8__k_10', 'Operation Setting 1__ar_coefficient__coeff_9__k_10', 'Operation Setting 1__ar_coefficient__coeff_10__k_10', 'Operation Setting 1__fft_coefficient__attr_"real"__coeff_9', 'Operation Setting 1__fft_coefficient__attr_"real"__coeff_10', 'Operation Setting 1__fft_coefficient__attr_"real"__coeff_11', 'Operation Setting 1__fft_coefficient__attr_"real"__coeff_12', 'Operation Setting 1__fft_coefficient__attr_"real"__coeff_13', 'Operation Setting 1__fft_coefficient__attr_"real"__coeff_14', 'Operation Setting 1__fft_coefficient__attr_"real"__coeff_15', 'Operation Setting 1__fft_coefficient__attr_"real"__coeff_16', 'Operation Setting 1__fft_coefficient__attr_"real"__coeff_17', 'Operation Setting 1__fft_coefficient__attr_"real"__coeff_18', 'Operation Setting 1__fft_coefficient__attr_"real"__coeff_19', 'Operation Setting 1__fft_coefficient__attr_"real"__coeff_20', 'Operation Setting 1__fft_coefficient__attr_"real"__coeff_21', 'Operation Setting 1__fft_coefficient__attr_"real"__coeff_22', 'Operation Setting 1__fft_coefficient__attr_"real"__coeff_23', 'Operation Setting 1__fft_coefficient__attr_"real"__coeff_24', 'Operation Setting 1__fft_coefficient__attr_"real"__coeff_25', 'Operation Setting 1__fft_coefficient__attr_"real"__coeff_26', 'Operation Setting 1__fft_coefficient__attr_"real"__coeff_27', 'Operation Setting 1__fft_coefficient__attr_"real"__coeff_28', 'Operation Setting 1__fft_coefficient__attr_"real"__coeff_29', 'Operation Setting 1__fft_coefficient__attr_"real"__coeff_30', 'Operation Setting 1__fft_coeff ...
# 10761

# %%
print(set(list_corr25_ds4) & set(list_const_ds4))
print(len(set(list_corr25_ds4) & set(list_const_ds4)))
# Out:
# set()
# 0

# %%
print(len(list_corr25_ds4)+len(list_const_ds4))
print(ds4_train.shape[1])
print("Remaining Features: ", ds4_train.shape[1] - (len(list_corr25_ds4)+len(list_const_ds4)))
# Out:
# 18604
# 18649
# Remaining Features:  45

# %%
drop_list = list_const_ds4 + list_corr25_ds4
ds4_rmn_fts = ds4_train.drop(columns=drop_list, inplace=False)

print(ds4_rmn_fts)
correlation.to_pickle("drive/MyDrive/PSDA/data/processed/dataset4_remaining_features_0519.pkl")
# Out:
#                   Operation Setting 1__sum_values  \
# UnitNumber Cycle
# 5          6                             179.0060
#            7                             221.0056
#            8                             241.0114
#            9                             276.0146
#            10                            311.0182
# ...                                           ...
# 93         192                           369.0294
#            193                           411.0307
#            194                           411.0289
#            195                           406.0284
#            196                           396.0237
#
#                   Operation Setting 1__abs_energy  \
# UnitNumber Cycle
# 5          6                          6103.446248
#            7                          7867.412649
#            8                          8267.644682
#            9                          9492.868692
#            10                        10718.120705
# ...                                           ...
# 93         192                       11203.901153
#            193                       12968.195160
#            194                       12968.105161
#            195                       12743.044157
#            196                       12642.920121
#
#                   Operation Setting 1__fft_coefficient__attr_"real"__coeff_0  \
# UnitNumber Cycle
# 5          6                                               179.0060
#            7                                               221.0056
#            8                                               241.0114
#            9                                               276.0146
#            10                                              311.0182
# ...                                                             ...
# 93         192                                             369.0294
#            193                                             411.0307
#            194                                             411.0289
#            195                                             406.0284
#            196                                             396.0237
#
#                   Operation Setting 1__fft_coefficient__attr_"abs"__coeff_0  \
# UnitNumber Cycle
# 5          6                                               179.0060
#            7                                               221.0056
#            8                                               241.0114
#            9                                               276.0146
#            10                                              311.0182
# ...                                                             ...
# 93         192                                             369.0294
#            193                                             411.0307
#            194                                             411.0289
#            195                                             406.0284
#            196                                             396.0237
#
#                   Operation Setting 2__sum_values  \
# UnitNumber Cycle
# 5          6                               4.0115
#            7                               4.8517
#            8                               5.5534
#            9                               6.3934
#            10                              7.2340
# ...                                           ...
# 93         192                             8.8611
#            193                             9.7012
#            194                             9.7013
#            195                             9.7802
#            196                             9.5295
#
#                   Operation Setting 2__abs_energy  \
# UnitNumber Cycle
# 5          6                             2.950622
#            7                             3.656558
#            8                             4.148940
#            9                             4.854540
#            10                            5.561149
# ...                                           ...
# 93         192                           6.201744
#            193                           6.907512
#            194                           6.907636
#            195                           7.011871
#            196                           6.948569
#
#                   Operation Setting 2__benford_correlation  \
# UnitNumber Cycle
# 5          6                                     -0.275681
#            7                                     -0.286250
#            8                                     -0.351643
#            9                                     -0.344119
#            10                                    -0.336694
# ...                                                    ...
# 93         192                                   -0.139440
#            193                                   -0.161391
#            194                                   -0.161391
#            195                                   -0.169626
#            196                                   -0.266753
#
#                   Operation Setting 2__fft_coefficient__attr_"real"__coeff_0  \
# UnitNumber Cycle
# 5          6                                                 4.0115
#            7                                                 4.8517
#            8                                                 5.5534
#            9                                                 6.3934
#            10                                                7.2340
# ...                                                             ...
# 93         192                                               8.8611
#            193                                               9.7012
#            194                                               9.7013
#            195                                               9.7802
#            196                                               9.5295
#
#                   Operation Setting 2__fft_coefficient__attr_"abs"__coeff_0  \
# UnitNumber Cycle
# 5          6                                                 4.0115
#            7                                                 4.8517
#            8                                                 5.5534
#            9                                                 6.3934
#            10                                                7.2340
# ...                                                             ...
# 93         192                                               8.8611
#            193                                               9.7012
#            194                                               9.7013
#            195                                               9.7802
#            196                                               9.5295
#
#                   Sensor Measure 6__ratio_value_number_to_time_series_length  \
# UnitNumber Cycle
# 5          6                                               0.833333
#            7                                               0.714286
#            8                                               0.750000
#            9                                               0.666667
#            10                                              0.600000
# ...                                                             ...
# 93         192                                             0.437500
#            193                                             0.375000
#            194                                             0.375000
#            195                                             0.375000
#            196                                             0.437500
#
#                   ...  Sensor Measure 15__median  \
# UnitNumber Cycle  ...
# 5          6      ...                    9.38835
#            7      ...                    9.38140
#            8      ...                    9.37465
#            9      ...                    9.36790
#            10     ...                    9.36225
# ...               ...                        ...
# 93         192    ...                    9.37810
#            193    ...                    9.40485
#            194    ...                    9.40485
#            195    ...                    9.37810
#            196    ...                    9.37810
#
#                   Sensor Measure 15__cwt_coefficients__coeff_0__w_20__widths_(2, 5, 10, 20)  \
# UnitNumber Cycle
# 5          6                                               5.255888
#            7                                               7.331230
#            8                                               7.280692
#            9                                               9.326526
#            10                                              9.243450
# ...                                                             ...
# 93         192                                            13.656729
#            193                                            13.730430
#            194                                            13.317322
#            195                                            12.898663
#            196                                            13.253869
#
#                   Sensor Measure 15__cwt_coefficients__coeff_1__w_20__widths_(2, 5, 10, 20)  \
# UnitNumber Cycle
# 5          6                                               7.368155
#            7                                               9.440877
#            8                                               9.392403
#            9                                              11.152941
#            10                                             11.076548
# ...                                                             ...
# 93         192                                            15.379853
#            193                                            15.439069
#            194                                            15.021883
#            195                                            14.948689
#            196                                            15.063932
#
#                   Sensor Measure 15__cwt_coefficients__coeff_2__w_20__widths_(2, 5, 10, 20)  \
# UnitNumber Cycle
# 5          6                                               9.471798
#            7                                              11.243662
#            8                                              11.208704
#            9                                              12.953262
#            10                                             12.890424
# ...                                                             ...
# 93         192                                            17.076142
#            193                                            17.127743
#            194                                            17.056012
#            195                                            16.746063
#            196                                            16.878654
#
#                   Sensor Measure 15__cwt_coefficients__coeff_3__w_10__widths_(2, 5, 10, 20)  \
# UnitNumber Cycle
# 5          6                                              15.429152
#            7                                              17.627931
#            8                                              17.549811
#            9                                              19.588906
#            10                                             19.372425
# ...                                                             ...
# 93         192                                            22.422100
#            193                                            22.670254
#            194                                            22.248963
#            195                                            21.874502
#            196                                            22.052625
#
#                   Sensor Measure 15__cwt_coefficients__coeff_3__w_20__widths_(2, 5, 10, 20)  \
# UnitNumber Cycle
# 5          6                                              11.257709
#            7                                              13.006863
#            8                                              12.992116
#            9                                              14.689564
#            10                                             14.647375
# ...                                                             ...
# 93         192                                            18.740270
#            193                                            19.130297
#            194                                            18.821788
#            195                                            18.535563
#            196                                            18.666200
#
#                   Sensor Measure 15__cwt_coefficients__coeff_4__w_20__widths_(2, 5, 10, 20)  \
# UnitNumber Cycle
# 5          6                                               9.619040
#            7                                              11.382959
#            8                                              14.704577
#            9                                              16.399906
#            10                                             16.384269
# ...                                                             ...
# 93         192                                            20.706387
#            193                                            20.849202
#            194                                            20.564385
#            195                                            20.285669
#            196                                            20.409740
#
#                   Sensor Measure 15__fft_coefficient__attr_"real"__coeff_0  \
# UnitNumber Cycle
# 5          6                                                58.6574
#            7                                                68.0253
#            8                                                77.2458
#            9                                                86.6024
#            10                                               95.9464
# ...                                                             ...
# 93         192                                             150.9334
#            193                                             151.8776
#            194                                             151.9100
#            195                                             150.2849
#            196                                             150.0526
#
#                   Sensor Measure 15__fft_coefficient__attr_"abs"__coeff_0  RUL
# UnitNumber Cycle
# 5          6                                                58.6574        188
#            7                                                68.0253        187
#            8                                                77.2458        186
#            9                                                86.6024        185
#            10                                               95.9464        184
# ...                                                             ...        ...
# 93         192                                             150.9334          5
#            193                                             151.8776          4
#            194                                             151.9100          3
#            195                                             150.2849          2
#            196                                             150.0526          1
#
# [2153 rows x 45 columns]

# %%
print(ds4_rmn_fts.columns)
wanted_features = ds4_rmn_fts.columns
# Out:
# Index(['Operation Setting 1__sum_values', 'Operation Setting 1__abs_energy',
#        'Operation Setting 1__fft_coefficient__attr_"real"__coeff_0',
#        'Operation Setting 1__fft_coefficient__attr_"abs"__coeff_0',
#        'Operation Setting 2__sum_values', 'Operation Setting 2__abs_energy',
#        'Operation Setting 2__benford_correlation',
#        'Operation Setting 2__fft_coefficient__attr_"real"__coeff_0',
#        'Operation Setting 2__fft_coefficient__attr_"abs"__coeff_0',
#        'Sensor Measure 6__ratio_value_number_to_time_series_length',
#        'Sensor Measure 7__permutation_entropy__dimension_4__tau_1',
#        'Sensor Measure 11__abs_energy', 'Sensor Measure 13__median',
#        'Sensor Measure 13__first_location_of_maximum',
#        'Sensor Measure 13__percentage_of_reoccurring_values_to_all_values',
#        'Sensor Measure 13__percentage_of_reoccurring_datapoints_to_all_datapoints',
#        'Sensor Measure 13__sum_of_reoccurring_values',
#        'Sensor Measure 13__sum_of_reoccurring_data_points',
#        'Sensor Measure 13__ratio_value_number_to_time_series_length',
#        'Sensor Measure 13__maximum', 'Sensor Measure 13__absolute_maximum',
#        'Sensor Measure 13__quantile__q_0.6',
#        'Sensor Measure 13__quantile__q_0.7',
#        'Sensor Measure 13__quantile__q_0.8',
#        'Sensor Measure 13__quantile__q_0.9',
#        'Sensor Measure 13__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.6',
#        'Sensor Measure 13__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"max"',
#        'Sensor Measure 14__maximum', 'Sensor Measure 14__absolute_maximum',
#        'Sensor Measure 14__quantile__q_0.4',
#        'Sensor Measure 14__quantile__q_0.9',
#        'Sensor Measure 14__binned_entropy__max_bins_10',
#        'Sensor Measure 14__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"max"',
#        'Sensor Measure 15__sum_values', 'Sensor Measure 15__abs_energy',
#        'Sensor Measure 15__median',
#        'Sensor Measure 15__cwt_coefficients__coeff_0__w_20__widths_(2, 5, 10, 20)',
#        'Sensor Measure 15__cwt_coefficients__coeff_1__w_20__widths_(2, 5, 10, 20)',
#        'Sensor Measure 15__cwt_coefficients__coeff_2__w_20__widths_(2, 5, 10, 20)',
#        'Sensor Measure 15__cwt_coefficients__coeff_3__w_10__widths_(2, 5, 10, 20)',
#        'Sensor Measure 15__cwt_coefficients__coeff_3__w_20__widths_(2, 5, 10, 20)',
#        'Sensor Measure 15__cwt_coefficients__coeff_4__w_20__widths_(2, 5, 10, 20)',
#        'Sensor Measure 15__fft_coefficient__attr_"real"__coeff_0',
#        'Sensor Measure 15__fft_coefficient__attr_"abs"__coeff_0', 'RUL'],
#       dtype='object')

# %%
if type(wanted_features) != list: string_list = wanted_features.copy().tolist()

for i in range(0,len(string_list)):
  string_list[i] = string_list[i].partition("__")[2]
  string_list[i] = string_list[i].partition("__")[0]
  #print(string_list[i])

wanted_features = string_list

print(wanted_features)
# Out:
# ['sum_values', 'abs_energy', 'fft_coefficient', 'fft_coefficient', 'sum_values', 'abs_energy', 'benford_correlation', 'fft_coefficient', 'fft_coefficient', 'ratio_value_number_to_time_series_length', 'permutation_entropy', 'abs_energy', 'median', 'first_location_of_maximum', 'percentage_of_reoccurring_values_to_all_values', 'percentage_of_reoccurring_datapoints_to_all_datapoints', 'sum_of_reoccurring_values', 'sum_of_reoccurring_data_points', 'ratio_value_number_to_time_series_length', 'maximum', 'absolute_maximum', 'quantile', 'quantile', 'quantile', 'quantile', 'change_quantiles', 'agg_linear_trend', 'maximum', 'absolute_maximum', 'quantile', 'quantile', 'binned_entropy', 'agg_linear_trend', 'sum_values', 'abs_energy', 'median', 'cwt_coefficients', 'cwt_coefficients', 'cwt_coefficients', 'cwt_coefficients', 'cwt_coefficients', 'cwt_coefficients', 'fft_coefficient', 'fft_coefficient', '']

# %%
from tsfresh.feature_extraction import feature_calculators
ds4_FCParameter = EfficientFCParameters().copy()

#for fname in feature_calculators.__dict__.keys():
#    if fname in ds4_FCParameter and fname in wanted_features:
#        print(fname)

for fname in feature_calculators.__dict__.keys():
    if fname in ds4_FCParameter and not fname in wanted_features:
        del ds4_FCParameter[fname]
# Out:
# WARNING:tsfresh.feature_extraction.settings:Dependency not available for matrix_profile, this feature will be disabled!
# sum_values
# abs_energy
# median
# first_location_of_maximum
# percentage_of_reoccurring_values_to_all_values
# percentage_of_reoccurring_datapoints_to_all_datapoints
# sum_of_reoccurring_values
# sum_of_reoccurring_data_points
# ratio_value_number_to_time_series_length
# fft_coefficient
# cwt_coefficients
# change_quantiles
# binned_entropy
# permutation_entropy
# quantile
# maximum
# absolute_maximum
# agg_linear_trend
# benford_correlation
